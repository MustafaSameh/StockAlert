# %% [markdown]
# # Testing Functions

# %%
import pandas as pd

# %%
data = pd.read_csv("exam_results_raw.csv")

# %%
data.head()
# Out:
#    student_id school_code  subject governorate      score  studied_hours  \
# 0        1089      SCH002  Science  Alexandria  62.600000            NaN
# 1        1086      SCH004  Science       Luxor  71.315907            4.0
# 2        1004      SCH003     Math       Aswan  58.000000            8.2
# 3        1087      SCH005   Arabic       Cairo  64.700000            8.3
# 4        1057      SCH003  Science       Aswan  81.305910            NaN
#
#   pass_fail
# 0      Pass
# 1      Pass
# 2      Pass
# 3      Pass
# 4      Pass

# %%
   data["studied_hours"].unique()
# Out:
# array([ nan,  4. ,  8.2,  8.3,  5.4,  6.1,  2.4,  2.2,  6.7,  7.5,  5.6,
#         3.7,  6.5,  9.2,  7.1,  4.1,  4.7,  3.6,  5.1,  2.3,  4.6,  5.7,
#         4.9,  1.9,  6. ,  2.8,  7.4,  5.3,  5.8,  5.9,  3.4,  7.2,  8. ,
#         3. ,  6.8,  8.5,  7.3,  4.8, 10. ,  8.4,  6.2,  8.1,  2.5,  4.4,
#         2.7,  9.8,  1.3,  2.6,  6.9,  5.5,  9.9,  4.3,  5. ,  9.6,  1.8,
#         5.2,  7. ,  3.9,  6.3,  3.8,  1.7,  3.2,  1.6,  3.1,  3.5,  3.3,
#         7.7,  1. ,  4.2,  9.3, -0.7,  4.5,  7.8,  2.9,  2.1,  1.5,  0.7,
#         6.4, -0.8, 10.2,  9.4,  8.8,  7.6,  0. ,  9.5])

# %%
data.describe()
# Out:
#         student_id       score  studied_hours
# count   318.000000  298.000000     306.000000
# mean   1048.710692   74.327657       5.170588
# std      29.815594   57.991554       2.079230
# min    1000.000000  -50.000000      -0.800000
# 25%    1023.000000   63.125000       3.700000
# 50%    1051.000000   71.950000       5.200000
# 75%    1073.750000   78.400000       6.500000
# max    1099.000000  999.000000      10.200000

# %%
data.duplicated().sum()
# Out:
# np.int64(10)

# %%
def duplicates_sentizer():
    global data
    if data.duplicated().sum() != 0 :  
       data = data.drop_duplicates().copy()
    return data.duplicated().sum()

# %%
duplicates_sentizer()
# Out:
# np.int64(0)

# %%
def outliers_sentizer():
    
    q1 = pd.Series(sorted(data["studied_hours"])).quantile(0.25)
    q3 = pd.Series(sorted(data["studied_hours"])).quantile(0.75)
    IQR = q3-q1
    upper_fence = q3 + 1.5 * IQR
    lower_fence = q1 + 1.5 * IQR
    data["studied_hours"] = data["studied_hours"].clip(lower_fence , upper_fence)

# %%
outliers_sentizer()

# %%
def nulls_sentizer(): 
       
    if data["studied_hours"].isna().sum() != 0 : 
        data["studied_hours"] = data["studied_hours"].fillna(data["studied_hours"].mean())
    return data.isna().sum()

# %%
nulls_sentizer()
# Out:
# student_id        0
# school_code       0
# subject           0
# governorate       0
# score            20
# studied_hours     0
# pass_fail        15
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 308 entries, 0 to 317
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   student_id     308 non-null    int64
#  1   school_code    308 non-null    object
#  2   subject        308 non-null    object
#  3   governorate    308 non-null    object
#  4   score          288 non-null    float64
#  5   studied_hours  308 non-null    float64
#  6   pass_fail      293 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 14.4+ KB

# %%
data.describe()
# Out:
#         student_id       score  studied_hours
# count   308.000000  288.000000     308.000000
# mean   1048.850649   74.898062       7.990572
# std      29.962579   58.689104       0.343358
# min    1000.000000  -50.000000       7.900000
# 25%    1022.750000   63.300000       7.900000
# 50%    1051.000000   72.100000       7.900000
# 75%    1074.000000   78.600000       7.900000
# max    1099.000000  999.000000      10.200000

# %%
def ROP ():
# Out:
#   Cell In[151], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
targted_sales = data.loc[data["student_id"] == 1089 ]
targted_sales
# Out:
#      student_id school_code  subject governorate  score  studied_hours  \
# 0          1089      SCH002  Science  Alexandria   62.6       7.990572
# 8          1089      SCH005  English       Cairo    NaN       7.900000
# 28         1089      SCH001  Science  Alexandria   75.2       7.900000
# 140        1089      SCH002  Science       Aswan   77.7       7.900000
# 177        1089      SCH005     Math  Alexandria   62.2       7.900000
# 275        1089      SCH001  Science       Cairo  -50.0       7.900000
# 307        1089      SCH001     Math        Giza   63.4       7.900000
#
#     pass_fail
# 0        Pass
# 8        Pass
# 28       Pass
# 140      Pass
# 177      Pass
# 275      Pass
# 307      Pass

# %%
   data["studied_hours"].unique()
# Out:
# array([ 7.99057239,  7.9       ,  8.2       ,  8.3       ,  9.2       ,
#         8.        ,  8.5       , 10.        ,  8.4       ,  8.1       ,
#         9.8       ,  9.9       ,  9.6       ,  9.3       , 10.2       ,
#         9.4       ,  8.8       ,  9.5       ])

# %%
def ROP ():
    global avg_sales
    global lead_time
    global _max_lead_time
    global _avg_lead_time
    lead_time = int(input("Please Enter the lead time of the product: "))
    _max_lead_time = int(input("Please Enter the Maximum lead time of the product: "))
    _avg_lead_time = int(input("Please Enter the Average lead time of the product: "))
    avg_sales = data["studied_hours"].mean()
    safety_stock =(max(data["studied_hours"]) * 10) - (avg_sales * 6)
    rop = (avg_sales * lead_time) + safety_stock
    return rop

# %%
ROP()
# Out:
# Please Enter the lead time of the product:  5
# Please Enter the Maximum lead time of the product:  5
# Please Enter the Average lead time of the product:  5
# np.float64(94.0094276094276)

# %%
avg_sales = data["studied_hours"].mean()
lead_time = int(input("Please Enter the lead time of the product: "))
# Out:
# Please Enter the lead time of the product:  5
# np.float64(39.952861952861944)

# %%
avg_sales * 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 avg_sales * 5
#
# NameError: name 'avg_sales' is not defined

# %% [markdown]
# # StockAlert x Sql

# %%
# %pip install mysql-connector-python

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="NewPassword123"
)

print(mydb)
# Out:
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# File /lib/python3.13/site-packages/mysql/connector/network.py:235, in NetworkBrokerPlain.recv(self, sock, address)
#     233 try:
#     234     # Read the header of the MySQL packet
# --> 235     header = self._recv_chunk(sock, size=PACKET_HEADER_LENGTH)
#     237     # Pull the payload length and sequence id
#
# File /lib/python3.13/site-packages/mysql/connector/network.py:180, in NetworkBrokerPlain._recv_chunk(self, sock, size)
#     179 while size:
# --> 180     read = sock.recv_into(pkt_view, size)
#     181     if read == 0 and size > 0:
#
# BlockingIOError: [Errno 6] Resource temporarily unavailable
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mydb = mysql.connector.connect(
#       2   host="localhost",
#       3   user="root",
#       4   password="NewPassword123"
#       5 )
#       7 print(mydb)
#
# File /lib/python3.13/site-packages/mysql/connector/pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File /lib/python3.13/site-packages/mysql/connector/connection.py:185, in MySQLConnection.__init__(self, **kwargs)
#     183 if kwargs:
#     184     try:
# --> 185         self.connect(**kwargs)
#     186     except Exception:
#     187         # Tidy-up underlying socket on failure
#     188         self.close()
#
# File /lib/python3.13/site-packages/mysql/connector/abstracts.py:1604, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1601     self.config(**kwargs)
#    1603 self.disconnect()
# -> 1604 self._open_connection()
#    1606 charset, collation = (
#    1607     kwargs.pop("charset", None),
#    1608     kwargs.pop("collation", None),
#    1609 )
#    1610 if charset or collation:
#
# File /lib/python3.13/site-packages/mysql/connector/connection.py:411, in MySQLConnection._open_connection(self)
#     406     if isinstance(err, (ReadTimeoutError, WriteTimeoutError)):
#     407         raise ConnectionTimeoutError(
#     408             errno=err.errno,
#     409             msg=err.msg,
#     410         ) from err
# --> 411     raise err
#     412 finally:
#     413     # as the connection is established, set back the read
#     414     # and write timeouts to the original value
#     415     self.read_timeout = stored_read_timeout
#
# File /lib/python3.13/site-packages/mysql/connector/connection.py:385, in MySQLConnection._open_connection(self)
#     382 self._socket.open_connection()
#     384 # do initial handshake
# --> 385 self._do_handshake()
#     387 # start authentication negotiation
#     388 self._do_auth(
#     389     self._user,
#     390     self._password,
#    (...)    394     self._conn_attrs,
#     395 )
#
# File /lib/python3.13/site-packages/mysql/connector/connection.py:214, in MySQLConnection._do_handshake(self)
#     212 def _do_handshake(self) -> None:
#     213     """Get the handshake from the MySQL server"""
# --> 214     packet = bytes(self._socket.recv())
#     215     if packet[4] == ERR_STATUS:
#     216         raise get_exception(packet)
#
# File /lib/python3.13/site-packages/mysql/connector/network.py:668, in MySQLSocket.recv(self, read_timeout)
#     665 except OSError as _:
#     666     # Ignore the OSError as the socket might not be setup properly
#     667     pass
# --> 668 return self._netbroker.recv(self.sock, self.address)
#
# File /lib/python3.13/site-packages/mysql/connector/network.py:248, in NetworkBrokerPlain.recv(self, sock, address)
#     246     raise ReadTimeoutError(errno=3024, msg=err.strerror) from err
#     247 except IOError as err:
# --> 248     raise OperationalError(
#     249         errno=2055, values=(address, _strioerror(err))
#     250     ) from err
#
# OperationalError: 2055: Lost connection to MySQL server at 'localhost:3306', system error: Errno 6: Resource temporarily unavailable
